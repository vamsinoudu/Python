# %%
x = min(20,0,5,0.1)             # min function
print(x)
# Out:
# 0

# %%
y = max(10,20,75)              # max function
print(y)
K = max(2.5,1.5,0.5)
print(K)
# Out:
# 75
# 2.5

# %%
x = pow(4,3)                   #power (x,y) function
print(x)
D = pow(2,2)
F = pow(3,2)
print(D)
print(F)
# Out:
# 64
# 4
# 9

# %%
import math                  # square root function
x = math.sqrt(64)
print(x)
# Out:
# 8.0

# %%
# math ceil and math floor

import math
x = math.ceil(2.1)
y = math.floor(2.9)
print(x)
print(y)
z = math.ceil(9.0)
c = math.ceil(8.5)
b = math.ceil(1.1)
print(z,c,b)
n = math.floor(2.5)
m = math.floor(1.1)
l = math.floor(2.9)
print(n,m,l)
# Out:
# 3
# 2
# 9 9 2
# 2 1 2

# %%
import math             # pi function
x = math.pi
print(x)
# Out:
# 3.141592653589793

# %%
import math                   # applying log function
z = math.log(50)
print(z)
s = math.log(3)
print(s)
# Out:
# 3.912023005428146
# 1.0986122886681098

# %%
math.pow(2,2)           # power function
# Out:
# 4.0

# %%
math.log(20)
# Out:
# 2.995732273553991

# %%
dir()                  #dir function
print(type(dir))
# Out:
# <class 'builtin_function_or_method'>

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'math.log(50)',
#   'x = min(20,0,5,0.1)\nprint(x)',
#   'y = max(10,20,75)\nprint(y)',
#   'x = pow(4,3)\nprint(x)',
#   'import math\nx = math.sqrt(64)\nprint(x)',
#   'import math\nx = math.ceil(2.1)\ny = math.floor(2.9)\nprint(x)\nprint(y)',
#   'import math\nx = math.pi\nprint(x)',
#   'import math\nz = math.log(50)\nprint(z)',
#   'x = pow(4,3)\nprint(x)\nD = pow(2,2)\nF = pow(3,2)\nprint(D)\nprint(F)',
#   'y = max(10,20,75)\nprint(y)\nK = max(2.5,1.5,0.5)\nprint(K)',
#   'import math\nx = math.ceil(2.1)\ny = math.floor(2.9)\nprint(x)\nprint(y)\nz = math.ceil(9.0)\nc = math.ceil(8.5)\nb = math.ceil(1.1)\nprint(z,c,b)',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'math.log(50)',
#   'x = min(20,0,5,0.1)\nprint(x)',
#   'y = max(10,20,75)\nprint(y)',
#   'x = pow(4,3)\nprint(x)',
#   'import math\nx = math.sqrt(64)\nprint(x)',
#   'import math\nx = math.ceil(2.1)\ny = math.floor(2.9)\nprint(x)\nprint(y)',
#   'import math\nx = math.pi\nprint(x)',
#   'import math\nz = math.log(50)\nprint(z)',
#   'x = pow(4,3)\nprint(x)\nD = pow(2,2)\nF = pow(3,2)\nprint(D)\nprint(F)',
#   'y = max(10,20,75)\nprint(y)\nK = max(2.5,1.5,0.5)\nprint(K)',
#   'import math\nx = math.ceil(2.1)\ny = math.floor(2.9)\nprint(x)\nprint(y)\nz = math.ceil(9.0)\nc = math.ceil(8.5)\nb = math.ceil(1.1)\nprint(z,c,b)',
# ...

# %%
n = 20
n = n+5
print(n)
# Out:
# 25

# %%
print(n)
m+=5
print(m)
# Out:
# 25
# 11

# %%
m-=5
print(m)
# Out:
# 6

# %%
z = 30
z/=5
print(z)
# Out:
# 6.0

# %%
a =3
b =5
b+=a-1
print(b)
# Out:
# 7
